# %%
x=[]
type(x)
# Out:
# list

# %%
x=[1,2,3,4,5]

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
x=[1,2.6,3+4j,"data"]

# %%
x
# Out:
# [1, 2.6, (3+4j), 'data']

# %%
type(x[2]),type(x[0]),type(x[1]),type(x[3])
# Out:
# (complex, int, float, str)

# %%
x=["data science","data analytics"]

# %%
x
# Out:
# ['data science', 'data analytics']

# %%
x[0][-3:-1]
# Out:
# 'nc'

# %%
[1,"data",3,4,[1,2,3]]
# Out:
# [1, 'data', 3, 4, [1, 2, 3]]

# %%
class_groups = [
    ["Abhi", "Vishal"],
    ["Kavitha", "rishita"],
    ["Ananya", "Rohiin"]
]

# %%
class_groups[2][0]
# Out:
# 'Ananya'

# %%
list1=[1,2,3,4,5]

# %%
list1.append(10)

# %%
list1
# Out:
# [1, 2, 'data', 'data', 'data', 'data', 3, 4, 5, 10, 10]

# %%
list1.insert(2,"data")

# %%
list1.pop(2)
# Out:
# 'data'

# %%
list1
# Out:
# [1, 2, 'data', 'data', 'data', 3, 4, 5, 10, 10]

# %%
list1=[1,2,3,4,5,6,7,1,1,1,1]

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 1, 1, 1, 1]

# %%
list1.count(1)
# Out:
# 5

# %%
list1.index(1)
# Out:
# 0

# %%
list1
# Out:
# [1, 2, 3, 4, 5, 6, 7, 1, 1, 1, 1]

# %%
list1.remove(1)

# %%
list1
# Out:
# [2, 3, 4, 5, 6, 7, 1, 1, 1, 1]

# %%
list1.clear()

# %%
list1
# Out:
# []

# %%
list1=[1,2,3,4,5,6]

# %%
list1.reverse()

# %%
list1
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
list1=["Abc","xyz","123"]

# %%
list1.sort(reverse=True)

# %%
list1
# Out:
# ['xyz', 'Abc', '123']

# %%
list1=[11,9,23,12]

# %%
list1.sort(reverse=True)
list1
# Out:
# [23, 12, 11, 9]

# %%
x=[1,2,3,4,5]

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y=x

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
y[3]=3333

# %%
y
# Out:
# [1, 2, 3, 3333, 5]

# %%
x
# Out:
# [1, 2, 3, 3333, 5]

# %%
x=[1,2,3,4,5]

# %%
x
# Out:
# [1, 2, 3, 4, 5]

# %%
y=x.copy()

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
y[2]=11111
