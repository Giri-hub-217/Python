# %%
retail_inventory = {
    "Electronics": {
        "Laptop": [55000, 30, "Dell"],
        "Mobile": [25000, 50, "Samsung"],
        "Tablet": [18000, 20, "Lenovo"],
        "Smart Watch": [7999, 40, "Noise"]
    },
    "Apparel": {
        "T-Shirt": [499, 100, "H&M"],
        "Jeans": [1199, 60, "Levi's"],
        "Jacket": [2499, 25, "Puma"]
    },
    "Home Appliances": {
        "Microwave": [8500, 15, "LG"],
        "Vacuum Cleaner": [7000, 10, "Philips"],
        "Refrigerator": [30000, 8, "Samsung"]
    }
}

# %%
 retail_inventory
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %%
retail_inventory ['Electronics']["Tablet"]
# Out:
# [18000, 20, 'Lenovo']

# %% [markdown]
# ## How do you get all the keys from a dictionary? (Use .keys())

# %%
retail_inventory.keys()
# Out:
# dict_keys(['Electronics', 'Apparel', 'Home Appliances'])

# %% [markdown]
# ## How do you get all the values from a dictionary? (Use .values())

# %%
retail_inventory.values()
# Out:
# dict_values([{'Laptop': [55000, 30, 'Dell'], 'Mobile': [25000, 50, 'Samsung'], 'Tablet': [18000, 20, 'Lenovo'], 'Smart Watch': [7999, 40, 'Noise']}, {'T-Shirt': [499, 100, 'H&M'], 'Jeans': [1199, 60, "Levi's"], 'Jacket': [2499, 25, 'Puma']}, {'Microwave': [8500, 15, 'LG'], 'Vacuum Cleaner': [7000, 10, 'Philips'], 'Refrigerator': [30000, 8, 'Samsung']}])

# %% [markdown]
# ## How do you retrieve the value for a specific key safely? (Use .get(key))

# %%
retail_inventory.get("Home Appliances")
# Out:
# {'Microwave': [8500, 15, 'LG'],
#  'Vacuum Cleaner': [7000, 10, 'Philips'],
#  'Refrigerator': [30000, 8, 'Samsung']}

# %% [markdown]
# ## How do you check if a key exists in a dictionary? (Use in)

# %%
"Jeans" in retail_inventory.get("Electronics")
# Out:
# False

# %% [markdown]
# ## How do you remove a key and return its value? (Use .pop(key))

# %%
retail_inventory ["Electronics"].pop('Mobile')
# Out:
# [25000, 50, 'Samsung']

# %%
retail_inventory
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %% [markdown]
# ## How do you copy a dictionary? (Use .copy())

# %%
retail_inventory.copy()
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %% [markdown]
# ## How do you remove all key-value pairs from a dictionary? (Use .clear())

# %%
retail_inventory.clear()

# %%
retail_inventory
# Out:
# {}

# %%
## How do you add or update a value for a key? (Use .update({key: value}))

# %%
retail_inventory.update({'Electronics': {'Laptop': [55000, 30, 'Dell'],
  'Mobile': [25000, 50, 'Samsung'],
  'Tablet': [18000, 20, 'Lenovo'],
  'Smart Watch': [7999, 40, 'Noise']},
 'Apparel': {'T-Shirt': [499, 100, 'H&M'],
  'Jeans': [1199, 60, "Levi's"],
  'Jacket': [2499, 25, 'Puma']},
 'Home Appliances': {'Microwave': [8500, 15, 'LG'],
  'Vacuum Cleaner': [7000, 10, 'Philips'],
  'Refrigerator': [30000, 8, 'Samsung']}})

# %%
retail_inventory
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %%
9.How do you retrieve both keys and values? (Use .items())

# %%
retail_inventory.items()
# Out:
# dict_items([('Electronics', {'Laptop': [55000, 30, 'Dell'], 'Mobile': [25000, 50, 'Samsung'], 'Tablet': [18000, 20, 'Lenovo'], 'Smart Watch': [7999, 40, 'Noise']}), ('Apparel', {'T-Shirt': [499, 100, 'H&M'], 'Jeans': [1199, 60, "Levi's"], 'Jacket': [2499, 25, 'Puma']}), ('Home Appliances', {'Microwave': [8500, 15, 'LG'], 'Vacuum Cleaner': [7000, 10, 'Philips'], 'Refrigerator': [30000, 8, 'Samsung']})])

# %%
10.How do you create an empty dictionary? (Use {} or dict())

# %%
retail_inventory={}

# %%
retail_inventory
# Out:
# {}

# %%
retail_inventory
# Out:
# {}

# %% [markdown]
# ## 11.Use .setdefault() to assign a default value to a missing key.

# %%
retail_inventory = {
    "Electronics": {
        "Laptop": [55000, 30, "Dell"],
        "Mobile": [25000, 50, "Samsung"],
        "Tablet": [18000, 20, "Lenovo"],
        "Smart Watch": [7999, 40, "Noise"]
    },
    "Apparel": {
        "T-Shirt": [499, 100, "H&M"],
        "Jeans": [1199, 60, "Levi's"],
        "Jacket": [2499, 25, "Puma"]
    },
    "Home Appliances": {
        "Microwave": [8500, 15, "LG"],
        "Vacuum Cleaner": [7000, 10, "Philips"],
        "Refrigerator": [30000, 8, "Samsung"]
    }
}

# %%
retail_inventory
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %%
retail_inventory.setdefault('Apparel',{'banana': [55000, 30, 'Dell'],
  'carrot': [25000, 50, 'Samsung'],
  'mango': [18000, 20, 'Lenovo'],
  'apple': [7999, 40, 'Noise']})
# Out:
# {'T-Shirt': [499, 100, 'H&M'],
#  'Jeans': [1199, 60, "Levi's"],
#  'Jacket': [2499, 25, 'Puma']}

# %%
retail_inventory
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %%
retail_inventory1 = {
    "Electronics": {
        "Laptop": [55000, 30, "Dell"],
        "Mobile": [25000, 50, "Samsung"],
        "Tablet": [18000, 20, "Lenovo"],
        "Smart Watch": [7999, 40, "Noise"]
    },
    "Apparel": {
        "T-Shirt": [499, 100, "H&M"],
        "Jeans": [1199, 60, "Levi's"],
        "Jacket": [2499, 25, "Puma"]
    },

}

# %%
retail_inventory1
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']}}

# %%
retail_inventory = {
    "Electronics": {
        "Laptop": [55000, 30, "Dell"],
        "Mobile": [25000, 50, "Samsung"],
        "Tablet": [18000, 20, "Lenovo"],
        "Smart Watch": [7999, 40, "Noise"]
    },
    "Apparel": {
        "T-Shirt": [499, 100, "H&M"],
        "Jeans": [1199, 60, "Levi's"],
        "Jacket": [2499, 25, "Puma"]
    },
    "Home Appliances": {
        "Microwave": [8500, 15, "LG"],
        "Vacuum Cleaner": [7000, 10, "Philips"],
        "Refrigerator": [30000, 8, "Samsung"]
    }
}

# %%
retail_inventory
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %% [markdown]
# ## Use .update() to merge two dictionaries.

# %%
retail_inventory1.update(retail_inventory)

# %%
retail_inventory1
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %% [markdown]
# ## Use .get() with a default return value if key is not found.

# %%
retail_inventory1.get('Factory',{'FYFRSF': [55000, 30, 'Dell'],
  'BGCBVFF': [25000, 50, 'Samsung'],
  'THFCV': [18000, 20, 'Lenovo'],
  'GVJNBC': [7999, 40, 'Noise']})

# %% [markdown]
# ## What’s the difference between .pop() and .popitem()? Try both.

# %%
retail_inventory1.pop('Apparel')
# Out:
# {'T-Shirt': [499, 100, 'H&M'],
#  'Jeans': [1199, 60, "Levi's"],
#  'Jacket': [2499, 25, 'Puma']}

# %%
retail_inventory1['Electronics'].popitem()
# Out:
# ('Smart Watch', [7999, 40, 'Noise'])

# %%
retail_inventory1
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %% [markdown]
# ## Use del to remove a key from a dictionary.

# %%
del retail_inventory['Home Appliances']

# %%
retail_inventory
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']}}

# %% [markdown]
# ## Get the number of keys in a dictionary.

# %%
len(retail_inventory)
# Out:
# 2

# %%
retail_inventory = {
    "Electronics": {
        "Laptop": [55000, 30, "Dell"],
        "Mobile": [25000, 50, "Samsung"],
        "Tablet": [18000, 20, "Lenovo"],
        "Smart Watch": [7999, 40, "Noise"]
    },
    "Apparel": {
        "T-Shirt": [499, 100, "H&M"],
        "Jeans": [1199, 60, "Levi's"],
        "Jacket": [2499, 25, "Puma"]
    },
    "Home Appliances": {
        "Microwave": [8500, 15, "LG"],
        "Vacuum Cleaner": [7000, 10, "Philips"],
        "Refrigerator": [30000, 8, "Samsung"]
    }
 }

# %%
retail_inventory
# Out:
# {'Electronics': {'Laptop': [55000, 30, 'Dell'],
#   'Mobile': [25000, 50, 'Samsung'],
#   'Tablet': [18000, 20, 'Lenovo'],
#   'Smart Watch': [7999, 40, 'Noise']},
#  'Apparel': {'T-Shirt': [499, 100, 'H&M'],
#   'Jeans': [1199, 60, "Levi's"],
#   'Jacket': [2499, 25, 'Puma']},
#  'Home Appliances': {'Microwave': [8500, 15, 'LG'],
#   'Vacuum Cleaner': [7000, 10, 'Philips'],
#   'Refrigerator': [30000, 8, 'Samsung']}}

# %% [markdown]
# ## Convert a list of tuples into a dictionary.

# %%
tuple2 = [(1, "one"), (2, "two"), (3, "three")]

# %%
tuple2
# Out:
# [(1, 'one'), (2, 'two'), (3, 'three')]

# %%
dict1 = dict(tuple2)

# %%
dict1
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %% [markdown]
# ## Create a dictionary from two lists: one of keys and one of values.

# %%
keys=["Ashok","Raju","Jasvik"]
values=["Manohar","prasad","nani"]

# %%
dict(zip(keys,values))
# Out:
# {'Ashok': 'Manohar', 'Raju': 'prasad', 'Jasvik': 'nani'}

# %% [markdown]
# ## Check if two dictionaries have the same keys.

# %%
dict1 = {"name": "Ashok", "age": 33, "city": "London"}
dict2 = {"name": "Raju", "age": 30, "city": "Uk"}
dict3 = {"name": "Jasvik", "age": 25, "country": "USA"}

# %%
(dict1.keys() == dict2.keys())
# Out:
# True

# %% [markdown]
# ## Check if a dictionary is empty.

# %%
retail_inventory={}
if not retail_inventory:
    print("Dictionary is empty")
else:
    print("Dictionary is not empty")
# Out:
# Dictionary is empty

# %%
if len(retail_inventory) == 0:
    print("Dictionary is empty")
# Out:
# Dictionary is empty
